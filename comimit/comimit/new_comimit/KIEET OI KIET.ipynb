# %%
import pandas as pd 
pd.read_parquet('map_org_all.parquet')
# Out:
#            Names  Index      frame name  frame idx
# 0       L01_V001      0  0000000000.jpg          0
# 1       L01_V001      1  0000000025.jpg         25
# 2       L01_V001      2  0000000050.jpg         50
# 3       L01_V001      3  0000000075.jpg         75
# 4       L01_V001      4  0000000100.jpg        100
# ...          ...    ...             ...        ...
# 776036  L20_V100    808  0000020200.jpg      20200
# 776037  L20_V100    809  0000020225.jpg      20225
# 776038  L20_V100    810  0000020250.jpg      20250
# 776039  L20_V100    811  0000020275.jpg      20275
# 776040  L20_V100    812  0000020300.jpg      20300
#
# [776041 rows x 4 columns]

# %%
import os
os.listdir("\mnt\d\AIgov\AIC2024\pank_keyframes\L01_V001".replace("\\",os.sep))
# Out:
# ['L01_V001_00000.jpg',
#  'L01_V001_00003.jpg',
#  'L01_V001_00009.jpg',
#  'L01_V001_00415.jpg',
#  'L01_V001_00467.jpg',
#  'L01_V001_00478.jpg',
#  'L01_V001_00531.jpg',
#  'L01_V001_00594.jpg',
#  'L01_V001_00597.jpg',
#  'L01_V001_00646.jpg',
#  'L01_V001_00717.jpg',
#  'L01_V001_00718.jpg',
#  'L01_V001_00726.jpg',
#  'L01_V001_00816.jpg',
#  'L01_V001_00842.jpg',
#  'L01_V001_00893.jpg',
#  'L01_V001_01714.jpg',
#  'L01_V001_01865.jpg',
#  'L01_V001_02059.jpg',
#  'L01_V001_02368.jpg',
#  'L01_V001_02598.jpg',
#  'L01_V001_02733.jpg',
#  'L01_V001_02840.jpg',
#  'L01_V001_02872.jpg',
#  'L01_V001_02927.jpg',
#  'L01_V001_03003.jpg',
#  'L01_V001_03117.jpg',
#  'L01_V001_03960.jpg',
#  'L01_V001_04004.jpg',
#  'L01_V001_04064.jpg',
#  'L01_V001_04120.jpg',
#  'L01_V001_04212.jpg',
#  'L01_V001_04235.jpg',
#  'L01_V001_04526.jpg',
#  'L01_V001_04682.jpg',
#  'L01_V001_05183.jpg',
#  'L01_V001_05308.jpg',
#  'L01_V001_05433.jpg',
#  'L01_V001_05558.jpg',
#  'L01_V001_05636.jpg',
# ...
